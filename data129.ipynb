# %%
person = "amit_fast_7"
file ="C:/Users/tanishqjasoria/Documents/Github/Rehab/gaitCycle-data/"+person+ "/test_data129.txt"
import numpy as np

# %%
f = open(file)
lines = []
time = []
pitch = []
roll = []
gyro = []
force = []
load = []
force_temp =[]
gyro_temp = []
load_temp = []
beta = 0.9

# %%
for line in f:
    lines.append(line)

# %%
print(lines)
# Out:
# ['=rz =-1  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =4.12  G2 =0.00  G3 =3.53\n', '\n', '.30  roll =40.76  gyrx =-4  gyry =0  gyrz =-1  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =4.12  G2 =0.00  G3 =3.53\n', '\n', 'time =0.3050 pitch =14.77  roll =6.61  gyrx =-2  gyry =-2  gyrz =-3  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.00  G3 =0.00\n', '\n', 'time =0.3180 pitch =27.12  roll =12.25  gyrx =0  gyry =0  gyrz =-5  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', '\n', 'time =0.3310 pitch =37.39  roll =16.96  gyrx =2  gyry =1  gyrz =-2  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.00  G3 =0.00\n', '\n', 'time =0.3450 pitch =45.78  roll =20.99  gyrx =4  gyry =2  gyrz =0  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', '\n', 'time =0.3580 pitch =52.79  roll =24.23  gyrx =4  gyry =6  gyrz =1  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', '\n', 'time =0.3710 pitch =58.92  roll =26.74  gyrx =2  gyry =6  gyrz =3  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', '\n', 'time =0.3850 pitch =64.39  roll =28.90  gyrx =0  gyry =4  gyrz =5  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', '\n', 'time =0.3980 pitch =69.24  roll =30.43  gyrx =-3  gyry =-1  gyrz =3  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', '\n', 'time =0.4110 pitch =73.36  roll =31.90  gyrx =-5  gyry =-3  gyrz =1  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', '\n', 'time =0.4240 pitch =76.62  roll =33.05  gyrx =-7  gyry =-2  gyrz =-2  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', '\n', 'time =0.4380 pitch =79.37  roll =34.11  gyrx =-7  gyry =-1  gyrz =-5  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', '\n', 'time =0.4520 pitch =81.89  roll =35.07  gyrx =-7  gyry =-2  gyrz =-6  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', '\n', 'time =0.4650 pitch =84.04  roll =36.17  gyrx =-7  gyry =-1  gyrz =-7  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', '\n', 'time =0.4790 pitch =85.85  roll =37.21  gyrx =-7  gyry =-3  gyrz =-8  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', '\n', 'time =0.4920 pitch =87.27  roll =38.34  gyrx =-5  gyry =-2  gyrz =-5  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', '\n', 'time =0.5050 pitch =88.32  roll =39.22  gyrx =-3  gyry =-2  gyrz =-4  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', '\n', 'time =0.5200 pitch =89.32  roll =40.09  gyrx =-1  gyry =-1  gyrz =-2  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =-2180.37  G3 =0.00\n', '\n', 'time =0.5410 pitch =90.42  roll =40.95  gyrx =0  gyry =2  gyrz =0  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', '\n', 'time =0.5550 pitch =91.54  roll =41.54  gyrx =1  gyry =2  gyrz =0  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', '\n', 'time =0.5680 pitch =92.28  roll =41.77  gyrx =3  gyry =2  gyrz =0  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.00  G3 =0.00\n', '\n', 'time =0.5810 pitch =92.73  roll =41.96  gyrx =4  gyry =2  gyrz =-2  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', '\n', 'time =0.5940 pitch =93.01  roll =41.92  gyrx =4  gyry =4  gyrz =-1  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', '\n', 'time =0.6080 pitch =93.26  roll =41.89  gyrx =3  gyry =3  gyrz =-2  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', '\n', 'time =0.6210 pitch =93.76  roll =41.99  gyrx =0  gyry =2  gyrz =-2  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00   ...

# %%
for elem in lines:
    if elem == '\n':
        lines.remove('\n')

# %%
for i in range(5):
    lines.pop(0)
    lines.pop()

# %%
print(lines)
# Out:
# ['time =0.3450 pitch =45.78  roll =20.99  gyrx =4  gyry =2  gyrz =0  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', 'time =0.3580 pitch =52.79  roll =24.23  gyrx =4  gyry =6  gyrz =1  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', 'time =0.3710 pitch =58.92  roll =26.74  gyrx =2  gyry =6  gyrz =3  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', 'time =0.3850 pitch =64.39  roll =28.90  gyrx =0  gyry =4  gyrz =5  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', 'time =0.3980 pitch =69.24  roll =30.43  gyrx =-3  gyry =-1  gyrz =3  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', 'time =0.4110 pitch =73.36  roll =31.90  gyrx =-5  gyry =-3  gyrz =1  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', 'time =0.4240 pitch =76.62  roll =33.05  gyrx =-7  gyry =-2  gyrz =-2  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', 'time =0.4380 pitch =79.37  roll =34.11  gyrx =-7  gyry =-1  gyrz =-5  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', 'time =0.4520 pitch =81.89  roll =35.07  gyrx =-7  gyry =-2  gyrz =-6  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', 'time =0.4650 pitch =84.04  roll =36.17  gyrx =-7  gyry =-1  gyrz =-7  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', 'time =0.4790 pitch =85.85  roll =37.21  gyrx =-7  gyry =-3  gyrz =-8  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', 'time =0.4920 pitch =87.27  roll =38.34  gyrx =-5  gyry =-2  gyrz =-5  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', 'time =0.5050 pitch =88.32  roll =39.22  gyrx =-3  gyry =-2  gyrz =-4  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', 'time =0.5200 pitch =89.32  roll =40.09  gyrx =-1  gyry =-1  gyrz =-2  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =-2180.37  G3 =0.00\n', 'time =0.5410 pitch =90.42  roll =40.95  gyrx =0  gyry =2  gyrz =0  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', 'time =0.5550 pitch =91.54  roll =41.54  gyrx =1  gyry =2  gyrz =0  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', 'time =0.5680 pitch =92.28  roll =41.77  gyrx =3  gyry =2  gyrz =0  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.00  G3 =0.00\n', 'time =0.5810 pitch =92.73  roll =41.96  gyrx =4  gyry =2  gyrz =-2  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', 'time =0.5940 pitch =93.01  roll =41.92  gyrx =4  gyry =4  gyrz =-1  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', 'time =0.6080 pitch =93.26  roll =41.89  gyrx =3  gyry =3  gyrz =-2  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', 'time =0.6210 pitch =93.76  roll =41.99  gyrx =0  gyry =2  gyrz =-2  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', 'time =0.6340 pitch =94.15  roll =41.94  gyrx =-2  gyry =0  gyrz =-2  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', 'time =0.6480 pitch =94.55  roll =41.93  gyrx =-4  gyry =-2  gyrz =-3  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.10\n', 'time =0.6620 pitch =94.72  roll =41.96  gyrx =-5  gyry =-1  gyrz =-4  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', 'time =0.6750 pitch =94.98  roll =42.06  gyrx =-4  gyry =-1  gyrz =-6  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', 'time =0.6890 pitch =95.33  roll =42.22  gyrx =-2  gyry =0  gyrz =-5  F1 =0  F2 =1  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.00  G2 =0.00  G3 =0.00\n', 'time =0.7020 pitch =95.38  roll =42.44  gyrx =0   ...

# %%
for line in lines:
    a = line.split("=")
    load_temp  = []
    gyro_temp  = []
    force_temp = []
    time.append((a[1].split(" "))[0].strip())
    pitch.append((a[2].split(" "))[0].strip())
    roll.append((a[3].split(" "))[0].strip())
    gyro_temp.append((a[4].split(" "))[0].strip())
    gyro_temp.append((a[5].split(" "))[0].strip())
    gyro_temp.append((a[6].split(" "))[0].strip())
    gyro.append(gyro_temp)
    force_temp.append((a[7].split(" "))[0].strip())
    force_temp.append((a[8].split(" "))[0].strip())
    force_temp.append((a[9].split(" "))[0].strip())
    force_temp.append((a[10].split(" "))[0].strip())
    force_temp.append((a[11].split(" "))[0].strip())
    force_temp.append((a[12].split(" "))[0].strip())
    force_temp.append((a[13].split(" "))[0].strip())
    force.append(force_temp)
    load_temp.append((a[14].split(" "))[0].strip())
    load_temp.append((a[15].split(" "))[0].strip())
    load_temp.append((a[16].split(" "))[0].strip())
    load.append(load_temp)
    print(a[1])
# Out:
# 0.3450 pitch
# 0.3580 pitch
# 0.3710 pitch
# 0.3850 pitch
# 0.3980 pitch
# 0.4110 pitch
# 0.4240 pitch
# 0.4380 pitch
# 0.4520 pitch
# 0.4650 pitch
# 0.4790 pitch
# 0.4920 pitch
# 0.5050 pitch
# 0.5200 pitch
# 0.5410 pitch
# 0.5550 pitch
# 0.5680 pitch
# 0.5810 pitch
# 0.5940 pitch
# 0.6080 pitch
# 0.6210 pitch
# 0.6340 pitch
# 0.6480 pitch
# 0.6620 pitch
# 0.6750 pitch
# 0.6890 pitch
# 0.7020 pitch
# 0.7150 pitch
# 0.7290 pitch
# 0.7420 pitch
# 0.7550 pitch
# 0.7690 pitch
# 0.7820 pitch
# 0.7950 pitch
# 0.8080 pitch
# 0.8220 pitch
# 0.8350 pitch
# 0.8480 pitch
# 0.8630 pitch
# 0.8760 pitch
# 0.8890 pitch
# 0.9030 pitch
# 0.9160 pitch
# 0.9290 pitch
# 0.9430 pitch
# 0.9560 pitch
# 0.9690 pitch
# 0.9830 pitch
# 0.9960 pitch
# 1.0090 pitch
# 1.0220 pitch
# 1.0360 pitch
# 1.0500 pitch
# 1.0630 pitch
# 1.0770 pitch
# 1.0900 pitch
# 1.1030 pitch
# 1.1170 pitch
# 1.1300 pitch
# 1.1430 pitch
# 1.1570 pitch
# 1.1700 pitch
# 1.1840 pitch
# 1.1980 pitch
# 1.2110 pitch
# 1.2240 pitch
# 1.2380 pitch
# 1.2520 pitch
# 1.2650 pitch
# 1.2780 pitch
# 1.2920 pitch
# 1.3050 pitch
# 1.3180 pitch
# 1.3320 pitch
# 1.3450 pitch
# 1.3580 pitch
# 1.3720 pitch
# 1.3850 pitch
# 1.3980 pitch
# 1.4120 pitch
# 1.4260 pitch
# 1.4390 pitch
# 1.4530 pitch
# 1.4660 pitch
# 1.4790 pitch
# 1.4920 pitch
# 1.5060 pitch
# 1.5190 pitch
# 1.5320 pitch
# 1.5460 pitch
# 1.5590 pitch
# 1.5720 pitch
# 1.5860 pitch
# 1.5990 pitch
# 1.6120 pitch
# 1.6260 pitch
# 1.6390 pitch
# 1.6530 pitch
# 1.6670 pitch
# 1.6800 pitch
# 1.6940 pitch
# 1.7080 pitch
# 1.7220 pitch
# 1.7350 pitch
# 1.7480 pitch
# 1.7630 pitch
# 1.7760 pitch
# 1.7890 pitch
# 1.8040 pitch
# 1.8170 pitch
# 1.8300 pitch
# 1.8450 pitch
# 1.8580 pitch
# 1.8720 pitch
# 1.8860 pitch
# 1.8990 pitch
# 1.9130 pitch
# 1.9270 pitch
# 1.9400 pitch
# 1.9540 pitch
# 1.9680 pitch
# 1.9810 pitch
# 1.9950 pitch
# 2.0090 pitch
# 2.0220 pitch
# 2.0360 pitch
# 2.0500 pitch
# 2.0630 pitch
# 2.0770 pitch
# 2.0910 pitch
# 2.1050 pitch
# 2.1180 pitch
# 2.1310 pitch
# 2.1450 pitch
# 2.1590 pitch
# 2.1720 pitch
# 2.1870 pitch
# 2.2000 pitch
# 2.2130 pitch
# 2.2280 pitch
# 2.2410 pitch
# 2.2550 pitch
# 2.2690 pitch
# 2.2820 pitch
# 2.2950 pitch
# 2.3100 pitch
# 2.3230 pitch
# 2.3360 pitch
# 2.3510 pitch
# 2.3640 pitch
# 2.3770 pitch
# 2.3920 pitch
# 2.4050 pitch
# 2.4180 pitch
# 2.4330 pitch
# 2.4460 pitch
# 2.4590 pitch
# 2.4730 pitch
# 2.4870 pitch
# 2.5000 pitch
# 2.5130 pitch
# 2.5280 pitch
# 2.5410 pitch
# 2.5540 pitch
# 2.5680 pitch
# 2.5820 pitch
# 2.5950 pitch
# 2.6090 pitch
# 2.6220 pitch
# 2.6350 pitch
# 2.6500 pitch
# 2.6630 pitch
# 2.6760 pitch
# 2.6900 pitch
# 2.7030 pitch
# 2.7170 pitch
# 2.7310 pitch
# 2.7440 pitch
# 2.7570 pitch
# 2.7700 pitch
# 2.7840 pitch
# 2.7980 pitch
# 2.8110 pitch
# 2.8250 pitch
# 2.8380 pitch
# 2.8510 pitch
# 2.8650 pitch
# 2.8780 pitch
# 2.8920 pitch
# 2.9060 pitch
# 2.9190 pitch
# 2.9320 pitch
# 2.9470 pitch
# 2.9600 pitch
# 2.9730 pitch
# 2.9870 pitch
# 3.0010 pitch
# 3.0140 pitch
# 3.0270 pitch
# 3.0410 pitch
# 3.0540 pitch
# 3.0680 pitch
# 3.0820 pitch
# 3.0950 pitch
# 3.1090 pitch
# 3.1230 pitch
# 3.1360 pitch
# 3.1500 pitch
# 3.1640 pitch
# 3.1770 pitch
# 3.1900 pitch
# 3.2050 pitch
# 3.2180 pitch
# 3.2310 pitch
# 3.2460 pitch
# 3.2590 pitch
# 3.2720 pitch
# 3.2870 pitch
# 3.3000 pitch
# 3.3130 pitch
# 3.3260 pitch
# 3.3410 pitch
# 3.3540 pitch
# 3.3670 pitch
# 3.3820 pitch
# 3.3950 pitch
# 3.4080 pitch
# 3.4220 pitch
# 3.4360 pitch
# 3.4490 pitch
# 3.4630 pitch
# 3.4770 pitch
# 3.4900 pitch
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-b47de0c0948e> in <module>()
#       9     gyro_temp.append((a[4].split(" "))[0].strip())
#      10     gyro_temp.append((a[5].split(" "))[0].strip())
# ---> 11     gyro_temp.append((a[6].split(" "))[0].strip())
#      12     gyro.append(gyro_temp)
#      13     force_temp.append((a[7].split(" "))[0].strip())
#
# IndexError: list index out of range

# %%
time = list(map(float, time))
pitch = list(map(float, pitch))
roll = list(map(float, roll))
for i in range(len(time)):
    load[i] = list(map(float, load[i]))
    force[i] = list(map(float, force[i]))
    gyro[i] = list(map(float, gyro[i]))

# %%
time = np.array(time)
pitch = np.array(pitch)
roll = np.array(roll)
force = np.array(force)
gyro = np.array(gyro)
load = np.array(load)

# %%
len(time)==len(pitch)==len(roll)==len(force)==len(gyro)==len(load)
# Out:
# True

# %%
for i in range(len(time)-1):
    pitch[i+1]=(beta)*pitch[i+1]+(1-beta)*pitch[i]
    roll[i+1]=beta*roll[i+1]+(1-beta)*roll[i]
    gyro[i+1]=beta*gyro[i+1]+(1-beta)*gyro[i]
    load[i+1]=beta*load[i+1]+(1-beta)*load[i]

# %%
a = "data129.txt"
d = open(a,"a+")

# %%
for i in range(len(time)):
    d.write(str(time[i]) + "  ")
    d.write(str(pitch[i]) + "  ")
    d.write(str(roll[i]) + "  ")
    for x in gyro[i]:
        d.write(str(x) + "  ")
    for x in force[i]:
        d.write(str(x) + "  ")
    for x in load[i]:
        d.write(str(x) + "  ")
    d.write("\n")

# %%
d.close()
