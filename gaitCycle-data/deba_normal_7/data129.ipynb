# %%
file = "/home/tanishqjasoria/Desktop/test_data34.txt"
import numpy as np

# %%
f = open(file)
lines = []
time = []
pitch = []
roll = []
gyro = []
force = []
load = []
force_temp =[]
gyro_temp = []
load_temp = []
beta = 0.9

# %%
for line in f:
    lines.append(line)

# %%
print(lines)
# Out:
# ['20  G2 =0.00  G3 =0.00\n', '\n', 'time =1.0160 pitch =49.62  roll =23.07  gyrx =-3  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.00  G3 =0.00\n', '\n', 'time =1.0300 pitch =49.68  roll =23.06  gyrx =-4  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.00  G3 =0.00\n', '\n', 'time =1.0430 pitch =49.80  roll =23.11  gyrx =-4  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', '\n', 'time =1.0550 pitch =49.85  roll =23.22  gyrx =-3  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', '\n', 'time =1.0690 pitch =49.76  roll =23.23  gyrx =-2  gyry =0  gyrz =-2  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', '\n', 'time =1.0820 pitch =49.55  roll =23.24  gyrx =-2  gyry =0  gyrz =-1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', '\n', 'time =1.0950 pitch =49.41  roll =23.22  gyrx =-3  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.10  G3 =0.00\n', '\n', 'time =1.1080 pitch =49.26  roll =23.23  gyrx =-4  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', '\n', 'time =1.1220 pitch =49.27  roll =23.22  gyrx =-5  gyry =0  gyrz =1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', '\n', 'time =1.1350 pitch =49.52  roll =23.32  gyrx =-5  gyry =-1  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', '\n', 'time =1.1480 pitch =49.82  roll =23.42  gyrx =-4  gyry =-1  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.29  G2 =0.00  G3 =0.00\n', '\n', 'time =1.1620 pitch =50.13  roll =23.58  gyrx =-4  gyry =-1  gyrz =-1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.29  G2 =0.00  G3 =0.00\n', '\n', 'time =1.1750 pitch =50.29  roll =23.67  gyrx =-2  gyry =0  gyrz =-1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', '\n', 'time =1.1880 pitch =50.20  roll =23.59  gyrx =-2  gyry =0  gyrz =-1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', '\n', 'time =1.2010 pitch =50.12  roll =23.55  gyrx =-1  gyry =0  gyrz =-1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', '\n', 'time =1.2140 pitch =50.06  roll =23.52  gyrx =-2  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.00  G3 =0.00\n', '\n', 'time =1.2270 pitch =50.00  roll =23.48  gyrx =-2  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.10  G3 =0.00\n', '\n', 'time =1.2410 pitch =50.03  roll =23.49  gyrx =-3  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', '\n', 'time =1.2540 pitch =49.99  roll =23.38  gyrx =-3  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', '\n', 'time =1.2670 pitch =50.11  roll =23.38  gyrx =-3  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', '\n', 'time =1.2800 pitch =50.04  roll =23.34  gyrx =-3  gyry =0  gyrz =-1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', '\n', 'time =1.2930 pitch =50.01  roll =23.32  gyrx =-2  gyry =0  gyrz =-2  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.00  G3 =0.00\n', '\n', 'time =1.3060 pitch =50.05  roll =23.37  gyrx =-2  gyry =-1  gyrz =-2  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', '\n', 'time =1.3190 pitch =49.89  roll =23.42  gyrx =-2  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.10  G3 =0.00\n', '\n', 'time =1.3330 pitch =49.48  roll =23.29  gyrx =-1  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', '\n', 'time =1.3460 pitch =49.29  ...

# %%
for elem in lines:
    if elem == '\n':
        lines.remove('\n')

# %%
for i in range(5):
    lines.pop(0)
    lines.pop()

# %%
print(lines)
# Out:
# ['time =1.0690 pitch =49.76  roll =23.23  gyrx =-2  gyry =0  gyrz =-2  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', 'time =1.0820 pitch =49.55  roll =23.24  gyrx =-2  gyry =0  gyrz =-1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', 'time =1.0950 pitch =49.41  roll =23.22  gyrx =-3  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.10  G3 =0.00\n', 'time =1.1080 pitch =49.26  roll =23.23  gyrx =-4  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', 'time =1.1220 pitch =49.27  roll =23.22  gyrx =-5  gyry =0  gyrz =1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', 'time =1.1350 pitch =49.52  roll =23.32  gyrx =-5  gyry =-1  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', 'time =1.1480 pitch =49.82  roll =23.42  gyrx =-4  gyry =-1  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.29  G2 =0.00  G3 =0.00\n', 'time =1.1620 pitch =50.13  roll =23.58  gyrx =-4  gyry =-1  gyrz =-1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.29  G2 =0.00  G3 =0.00\n', 'time =1.1750 pitch =50.29  roll =23.67  gyrx =-2  gyry =0  gyrz =-1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', 'time =1.1880 pitch =50.20  roll =23.59  gyrx =-2  gyry =0  gyrz =-1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', 'time =1.2010 pitch =50.12  roll =23.55  gyrx =-1  gyry =0  gyrz =-1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', 'time =1.2140 pitch =50.06  roll =23.52  gyrx =-2  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.00  G3 =0.00\n', 'time =1.2270 pitch =50.00  roll =23.48  gyrx =-2  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.10  G3 =0.00\n', 'time =1.2410 pitch =50.03  roll =23.49  gyrx =-3  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', 'time =1.2540 pitch =49.99  roll =23.38  gyrx =-3  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', 'time =1.2670 pitch =50.11  roll =23.38  gyrx =-3  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', 'time =1.2800 pitch =50.04  roll =23.34  gyrx =-3  gyry =0  gyrz =-1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.00  G3 =0.00\n', 'time =1.2930 pitch =50.01  roll =23.32  gyrx =-2  gyry =0  gyrz =-2  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.00  G3 =0.00\n', 'time =1.3060 pitch =50.05  roll =23.37  gyrx =-2  gyry =-1  gyrz =-2  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', 'time =1.3190 pitch =49.89  roll =23.42  gyrx =-2  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.10  G3 =0.00\n', 'time =1.3330 pitch =49.48  roll =23.29  gyrx =-1  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', 'time =1.3460 pitch =49.29  roll =23.23  gyrx =-1  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', 'time =1.3590 pitch =48.91  roll =22.98  gyrx =-2  gyry =0  gyrz =1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.10  G2 =0.00  G3 =0.00\n', 'time =1.3730 pitch =48.74  roll =22.91  gyrx =-2  gyry =0  gyrz =1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', 'time =1.3850 pitch =48.86  roll =22.86  gyrx =-2  gyry =0  gyrz =0  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', 'time =1.3980 pitch =49.33  roll =23.01  gyrx =-2  gyry =-1  gyrz =-1  F1 =0  F2 =0  F3 =0  F4 =0  F5 =0  F6 =0  F7 =0  G1 =0.20  G2 =0.10  G3 =0.00\n', 'time =1.4120 pitch =49.61  roll =23.10  gyrx =-2  gyry =0 ...

# %%
for line in lines:
    a = line.split("=")
    load_temp  = []
    gyro_temp  = []
    force_temp = []
    time.append((a[1].split(" "))[0].strip())
    pitch.append((a[2].split(" "))[0].strip())
    roll.append((a[3].split(" "))[0].strip())
    gyro_temp.append((a[4].split(" "))[0].strip())
    gyro_temp.append((a[5].split(" "))[0].strip())
    gyro_temp.append((a[6].split(" "))[0].strip())
    gyro.append(gyro_temp)
    force_temp.append((a[7].split(" "))[0].strip())
    force_temp.append((a[8].split(" "))[0].strip())
    force_temp.append((a[9].split(" "))[0].strip())
    force_temp.append((a[10].split(" "))[0].strip())
    force_temp.append((a[11].split(" "))[0].strip())
    force_temp.append((a[12].split(" "))[0].strip())
    force_temp.append((a[13].split(" "))[0].strip())
    force.append(force_temp)
    load_temp.append((a[14].split(" "))[0].strip())
    load_temp.append((a[15].split(" "))[0].strip())
    load_temp.append((a[16].split(" "))[0].strip())
    load.append(load_temp)

# %%
time = list(map(float, time))
pitch = list(map(float, pitch))
roll = list(map(float, roll))
for i in range(len(time)):
    load[i] = list(map(float, load[i]))
    force[i] = list(map(float, force[i]))
    gyro[i] = list(map(float, gyro[i]))

# %%
time = np.array(time)
pitch = np.array(pitch)
roll = np.array(roll)
force = np.array(force)
gyro = np.array(gyro)
load = np.array(load)
# Out:
# [0.2, 0.1, 0.0]

# %%
len(time)==len(pitch)==len(roll)==len(force)==len(gyro)==len(load)
# Out:
# True

# %%
for i in range(len(time)-1):
    pitch[i+1]=(beta*10)*pitch[i+1]+(10-beta*10)*pitch[i]
    roll[i+1]=beta*roll[i+1]+(1-beta)*roll[i]
    gyro[i+1]=beta*gyro[i+1]+(1-beta)*gyro[i]
    load[i+1]=beta*load[i+1]+(1-beta)*load[i]
